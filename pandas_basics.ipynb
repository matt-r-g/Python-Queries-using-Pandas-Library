# %% [markdown]
# making a dataset

# %%
pip install pandas

# %%
import pandas as pd

# %%
data = {"calories": [420, 380, 390],
        "duration": [50, 40, 45]}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# importing dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-273d8114-2e52-47a7-921e-1589b1e14684" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-273d8114-2e52-47a7-921e-1589b1e14684">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("student.csv")

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.head(10)
# Out:
#    id         name  class  mark  gender
# 0   1     John Deo   Four    75  female
# 1   2     Max Ruin  Three    85    male
# 2   3       Arnold  Three    55    male
# 3   4   Krish Star   Four    60  female
# 4   5    John Mike   Four    60  female
# 5   6    Alex John   Four    55    male
# 6   7  My John Rob  Fifth    78    male
# 7   8       Asruid   Five    85    male
# 8   9      Tes Qry    Six    78     NaN
# 9  10     Big John   Four    55  female

# %%
df.tail()
# Out:
#     id         name  class  mark  gender
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df.sample()
# Out:
#     id       name class  mark  gender
# 32  33  Kenn Rein   Six    96  female

# %%
df.sample(3)
# Out:
#     id         name  class  mark gender
# 6    7  My John Rob  Fifth    78   male
# 22  23        Herod  Eight    79   male
# 28  29  Tess Played  Seven    55   male

# %%
df.shape
# Out:
# (35, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    34 non-null     object
#  2   class   34 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  33 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df.columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
df.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id        0
# name      1
# class     1
# mark      0
# gender    2
# dtype: int64

# %%
df.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %% [markdown]
# subsetting a dataframe

# %%
df["name"]
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26            NaN
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %%
df["class"].head()
# Out:
# 0     Four
# 1    Three
# 2    Three
# 3     Four
# 4     Four
# Name: class, dtype: object

# %%
df["mark"].mean()
# Out:
# 74.65714285714286

# %%
df["mark"].max()
# Out:
# 96

# %%
df[["name","gender","id"]].sample()
# Out:
#      name gender  id
# 18  Tinny   male  19

# %% [markdown]
# using indexes

# %%
df["name"][0:2]
# Out:
# 0    John Deo
# 1    Max Ruin
# Name: name, dtype: object

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df[1:5]
# Out:
#    id        name  class  mark  gender
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df["name"][0:2]
# Out:
# 0    John Deo
# 1    Max Ruin
# Name: name, dtype: object

# %% [markdown]
# Loc and iLoc

# %%
df.loc[0, "name"] # first row and name column
# loc[rows, columns]
# Out:
# 'John Deo'

# %%
df.loc[3, "mark"]
# Out:
# 60

# %%
df.loc[3, ["name", "mark"]]
# Out:
# name    Krish Star
# mark            60
# Name: 3, dtype: object

# %%
df.loc[0:3, ["name", "mark"]]
# Out:
#          name  mark
# 0    John Deo    75
# 1    Max Ruin    85
# 2      Arnold    55
# 3  Krish Star    60

# %%
df.iloc[3,3]
# Out:
# 60

# %%
df.iloc[0:3, [1,2]]
# Out:
#        name  class
# 0  John Deo   Four
# 1  Max Ruin  Three
# 2    Arnold  Three

# %% [markdown]
# Filtering

# %%
df[df["mark"]>90]
# Out:
#     id       name class  mark  gender
# 11  12      Recky   Six    94  female
# 32  33  Kenn Rein   Six    96  female

# %%
df.loc[df["mark"]>90, :]
# Out:
#     id       name class  mark  gender
# 11  12      Recky   Six    94  female
# 32  33  Kenn Rein   Six    96  female

# %%
df[df["gender"]=="female"]
# Out:
#     id        name  class  mark  gender
# 0    1    John Deo   Four    75  female
# 3    4  Krish Star   Four    60  female
# 4    5   John Mike   Four    60  female
# 9   10    Big John   Four    55  female
# 10  11      Ronald    Six    89  female
# 11  12       Recky    Six    94  female
# 12  13         Kty  Seven    88  female
# 13  14        Bigy  Seven    88  female
# 19  20      Jackly   Nine    65  female
# 20  21  Babby John   Four    69  female
# 21  22      Reggid  Seven    55  female
# 27  28   Rojj Base  Seven    86  female
# 29  30   Reppy Red    Six    79  female
# 31  32   Binn Rott  Seven    90  female
# 32  33   Kenn Rein    Six    96  female
# 34  35  Rows Noump    Six    88  female

# %%
df.loc[df["gender"]=="female", :]
# Out:
#     id        name  class  mark  gender
# 0    1    John Deo   Four    75  female
# 3    4  Krish Star   Four    60  female
# 4    5   John Mike   Four    60  female
# 9   10    Big John   Four    55  female
# 10  11      Ronald    Six    89  female
# 11  12       Recky    Six    94  female
# 12  13         Kty  Seven    88  female
# 13  14        Bigy  Seven    88  female
# 19  20      Jackly   Nine    65  female
# 20  21  Babby John   Four    69  female
# 21  22      Reggid  Seven    55  female
# 27  28   Rojj Base  Seven    86  female
# 29  30   Reppy Red    Six    79  female
# 31  32   Binn Rott  Seven    90  female
# 32  33   Kenn Rein    Six    96  female
# 34  35  Rows Noump    Six    88  female

# %%
df.loc[df["gender"]=="female", ["name", "class", "gender"]]
# Out:
#           name  class  gender
# 0     John Deo   Four  female
# 3   Krish Star   Four  female
# 4    John Mike   Four  female
# 9     Big John   Four  female
# 10      Ronald    Six  female
# 11       Recky    Six  female
# 12         Kty  Seven  female
# 13        Bigy  Seven  female
# 19      Jackly   Nine  female
# 20  Babby John   Four  female
# 21      Reggid  Seven  female
# 27   Rojj Base  Seven  female
# 29   Reppy Red    Six  female
# 31   Binn Rott  Seven  female
# 32   Kenn Rein    Six  female
# 34  Rows Noump    Six  female

# %% [markdown]
# filtering by 2 criteria

# %%
df[(df["gender"]=="female") & (df["class"]=="Six")]
# Out:
#     id        name class  mark  gender
# 10  11      Ronald   Six    89  female
# 11  12       Recky   Six    94  female
# 29  30   Reppy Red   Six    79  female
# 32  33   Kenn Rein   Six    96  female
# 34  35  Rows Noump   Six    88  female

# %%
df.loc[(df["gender"]=="female") & (df["class"]=="Six"), :]
# Out:
#     id        name class  mark  gender
# 10  11      Ronald   Six    89  female
# 11  12       Recky   Six    94  female
# 29  30   Reppy Red   Six    79  female
# 32  33   Kenn Rein   Six    96  female
# 34  35  Rows Noump   Six    88  female

# %%
df["mark"].mean()
# Out:
# 74.65714285714286

# %% [markdown]
# Average mark across male and female students

# %%
df[df["gender"] == "female"]["mark"].mean()
# Out:
# 77.3125

# %% [markdown]
# average mark for male

# %%
df[df["gender"] == "male"]["mark"].mean()
# Out:
# 71.58823529411765

# %% [markdown]
# Max and min mark

# %%
df["mark"].min()
# Out:
# 18

# %%
df["mark"].max()
# Out:
# 96

# %% [markdown]
# Max mark for male and female students

# %%
df[df["gender"] == "male"]["mark"].max()
# Out:
# 88

# %%
df[df["gender"] == "female"]["mark"].max()
# Out:
# 96

# %% [markdown]
# Average mark for class 'Five'

# %%
df[df["class"] == "Five"]["mark"].mean()
# Out:
# 80.0

# %% [markdown]
# Average mark for class 'Six' and male students only

# %%
df[(df["class"] == "Six") & (df["gender"] == "male")]["mark"].mean()
# Out:
# 54.0

# %%
df.loc[(df["class"]=="Six") & (df["gender"]=="male")]["mark"].mean()
# Out:
# 54.0

# %%
df[(df["gender"]=="male") & (df["class"]=="Six")]["mark"].mean()
# Out:
# 54.0

# %% [markdown]
# group by - to group results as previously searched separately

# %%
df.groupby("gender")["mark"].mean()
# Out:
# gender
# female    77.312500
# male      71.588235
# Name: mark, dtype: float64

# %% [markdown]
# student who has lowest mark (18)

# %%
df[df["mark"]==18]
# Out:
#     id   name class  mark gender
# 18  19  Tinny  Nine    18   male

# %%
df.loc[df["mark"]==df['mark'].min()]
# Out:
#     id   name class  mark gender
# 18  19  Tinny  Nine    18   male

# %% [markdown]
# Sorting results

# %%
df.sort_values(by="name")
# Out:
#     id         name  class  mark  gender
# 5    6    Alex John   Four    55    male
# 2    3       Arnold  Three    55    male
# 7    8       Asruid   Five    85    male
# 20  21   Babby John   Four    69  female
# 9   10     Big John   Four    55  female
# 13  14         Bigy  Seven    88  female
# 31  32    Binn Rott  Seven    90  female
# 25  26       Crelea  Seven    79    male
# 33  34     Gain Toe  Seven    69    male
# 24  25     Giff Tow  Seven    88    male
# 15  16        Gimmy   Four    88    male
# 22  23        Herod  Eight    79    male
# 17  18        Honny   Five    75    male
# 19  20       Jackly   Nine    65  female
# 0    1     John Deo   Four    75  female
# 4    5    John Mike   Four    60  female
# 32  33    Kenn Rein    Six    96  female
# 3    4   Krish Star   Four    60  female
# 12  13          Kty  Seven    88  female
# 30  31  Marry Toeey   Four    88    male
# 1    2     Max Ruin  Three    85    male
# 6    7  My John Rob  Fifth    78    male
# ...

# %% [markdown]
# sorting ascending or descending order

# %%
df.sort_values(by="name", ascending=False)
# Out:
#     id         name  class  mark  gender
# 16  17        Tumyu    Six    54    male
# 18  19        Tinny   Nine    18    male
# 23  24    Tiddy Now  Seven    78    male
# 28  29  Tess Played  Seven    55    male
# 8    9      Tes Qry    Six    78     NaN
# 14  15     Tade Row    NaN    88    male
# 34  35   Rows Noump    Six    88  female
# 10  11       Ronald    Six    89  female
# 27  28    Rojj Base  Seven    86  female
# 29  30    Reppy Red    Six    79  female
# 21  22       Reggid  Seven    55  female
# 11  12        Recky    Six    94  female
# 6    7  My John Rob  Fifth    78    male
# 1    2     Max Ruin  Three    85    male
# 30  31  Marry Toeey   Four    88    male
# 12  13          Kty  Seven    88  female
# 3    4   Krish Star   Four    60  female
# 32  33    Kenn Rein    Six    96  female
# 4    5    John Mike   Four    60  female
# 0    1     John Deo   Four    75  female
# 19  20       Jackly   Nine    65  female
# 17  18        Honny   Five    75    male
# ...

# %%
df.sort_values(by="name", ascending=True)
# Out:
#     id         name  class  mark  gender
# 5    6    Alex John   Four    55    male
# 2    3       Arnold  Three    55    male
# 7    8       Asruid   Five    85    male
# 20  21   Babby John   Four    69  female
# 9   10     Big John   Four    55  female
# 13  14         Bigy  Seven    88  female
# 31  32    Binn Rott  Seven    90  female
# 25  26       Crelea  Seven    79    male
# 33  34     Gain Toe  Seven    69    male
# 24  25     Giff Tow  Seven    88    male
# 15  16        Gimmy   Four    88    male
# 22  23        Herod  Eight    79    male
# 17  18        Honny   Five    75    male
# 19  20       Jackly   Nine    65  female
# 0    1     John Deo   Four    75  female
# 4    5    John Mike   Four    60  female
# 32  33    Kenn Rein    Six    96  female
# 3    4   Krish Star   Four    60  female
# 12  13          Kty  Seven    88  female
# 30  31  Marry Toeey   Four    88    male
# 1    2     Max Ruin  Three    85    male
# 6    7  My John Rob  Fifth    78    male
# ...

# %% [markdown]
# limit the results to a specific number while sorting ascending/descending

# %%
df.sort_values(by="mark", ascending=False).head(10)
# Out:
#     id        name  class  mark  gender
# 32  33   Kenn Rein    Six    96  female
# 11  12       Recky    Six    94  female
# 31  32   Binn Rott  Seven    90  female
# 10  11      Ronald    Six    89  female
# 24  25    Giff Tow  Seven    88    male
# 15  16       Gimmy   Four    88    male
# 14  15    Tade Row    NaN    88    male
# 13  14        Bigy  Seven    88  female
# 12  13         Kty  Seven    88  female
# 34  35  Rows Noump    Six    88  female

# %% [markdown]
# using OR

# %%
df[(df["gender"]=="female") | (df["class"]=="Seven")].sort_values(by="mark")
# Out:
#     id         name  class  mark  gender
# 21  22       Reggid  Seven    55  female
# 9   10     Big John   Four    55  female
# 28  29  Tess Played  Seven    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 19  20       Jackly   Nine    65  female
# 33  34     Gain Toe  Seven    69    male
# 20  21   Babby John   Four    69  female
# 0    1     John Deo   Four    75  female
# 23  24    Tiddy Now  Seven    78    male
# 25  26       Crelea  Seven    79    male
# 29  30    Reppy Red    Six    79  female
# 27  28    Rojj Base  Seven    86  female
# 12  13          Kty  Seven    88  female
# 24  25     Giff Tow  Seven    88    male
# 13  14         Bigy  Seven    88  female
# 34  35   Rows Noump    Six    88  female
# 10  11       Ronald    Six    89  female
# 31  32    Binn Rott  Seven    90  female
# 11  12        Recky    Six    94  female
# 32  33    Kenn Rein    Six    96  female

# %% [markdown]
# value counts - used to count the unique values in each column

# %%
df["class"].value_counts()
# Out:
# class
# Seven    10
# Four      8
# Six       7
# Three     3
# Five      2
# Nine      2
# Fifth     1
# Eight     1
# Name: count, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# gender
# male      17
# female    16
# Name: count, dtype: int64
